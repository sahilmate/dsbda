# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('academic_data.csv')

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    NaN    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    NaN    84   98.0   84
# 5         WS   Thakur      F   87.0   NaN   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0   NaN   93.0   96
# 10        MN    Desai      F  200.0    87    NaN  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300
# 12        DS    Patel      F  300.0   NaN   88.0  100
# 13        XY    Patel      F  300.0   NaN   88.0  200
# 14        BC    Patel      F  300.0   NaN   88.0  300

# %%
missing_values_formats = ['N.A', '?', 'na', 'N/A', 'NA', '--', 'N/a']
df = pd.read_csv('academic_data.csv', na_values=missing_values_formats)

# %%
df['SPOS'].head(10)
# Out:
# 0    85.0
# 1    90.0
# 2     NaN
# 3    95.0
# 4     NaN
# 5    87.0
# 6    81.0
# 7    40.0
# 8    10.0
# 9     9.0
# Name: SPOS, dtype: float64

# %%
df['SPOS'].isnull().head(10)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: SPOS, dtype: bool

# %%
df['SPOS'].notnull().head(10)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: SPOS, dtype: bool

# %%
null_filter = df['SPOS'].notnull()
df[null_filter]
# Out:
#    Firstname Lastname Gender   SPOS  DSBDA     WT     DA
# 0         LA      Roy      M   85.0   88.0   90.0   92.0
# 1         SA    Dixit      F   90.0   90.0   94.0   95.0
# 3         DA   Kapoor      M   95.0   86.0  500.0   82.0
# 5         WS   Thakur      F   87.0    NaN   97.0   86.0
# 6         DY   Kapoor      M   81.0   80.0   96.0   89.0
# 7         JK   Khanna      F   40.0   88.0   95.0   87.0
# 8         RT  Pardesi      M   10.0   96.0   94.0   88.0
# 9         UV  Pardesi      M    9.0    NaN   93.0   96.0
# 10        MN    Desai      F  200.0   87.0    NaN    NaN
# 11        BC    Patel      F  300.0    NaN   88.0  300.0
# 12        DS    Patel      F  300.0    NaN   88.0  100.0
# 13        XY    Patel      F  300.0    NaN   88.0  200.0
# 14        BC    Patel      F  300.0    NaN   88.0  300.0

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = pd.read_csv('academic_data.csv')

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    NaN    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    NaN    84   98.0   84
# 5         WS   Thakur      F   87.0   NaN   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0   NaN   93.0   96
# 10        MN    Desai      F  200.0    87    NaN  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300
# 12        DS    Patel      F  300.0   NaN   88.0  100
# 13        XY    Patel      F  300.0   NaN   88.0  200
# 14        BC    Patel      F  300.0   NaN   88.0  300

# %%
new_df = df.dropna(axis = 1, how = 'any')

# %%
new_df
# Out:
#    Firstname Lastname Gender   DA
# 0         LA      Roy      M   92
# 1         SA    Dixit      F   95
# 2         AB   Danial      M   80
# 3         DA   Kapoor      M   82
# 4         SA      Jha      F   84
# 5         WS   Thakur      F   86
# 6         DY   Kapoor      M   89
# 7         JK   Khanna      F   87
# 8         RT  Pardesi      M   88
# 9         UV  Pardesi      M   96
# 10        MN    Desai      F  N.A
# 11        BC    Patel      F  300
# 12        DS    Patel      F  100
# 13        XY    Patel      F  200
# 14        BC    Patel      F  300

# %%
df['SPOS'].fillna(0, inplace = True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_31372\1845457061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SPOS'].fillna(0, inplace = True)

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    0.0    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    0.0    84   98.0   84
# 5         WS   Thakur      F   87.0   NaN   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0   NaN   93.0   96
# 10        MN    Desai      F  200.0    87    NaN  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300
# 12        DS    Patel      F  300.0   NaN   88.0  100
# 13        XY    Patel      F  300.0   NaN   88.0  200
# 14        BC    Patel      F  300.0   NaN   88.0  300

# %%
df['WT'].fillna(method = 'pad', inplace = True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_31372\1402228085.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WT'].fillna(method = 'pad', inplace = True)
# C:\Users\sahil\AppData\Local\Temp\ipykernel_31372\1402228085.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['WT'].fillna(method = 'pad', inplace = True)

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    0.0    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    0.0    84   98.0   84
# 5         WS   Thakur      F   87.0   NaN   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0   NaN   93.0   96
# 10        MN    Desai      F  200.0    87   93.0  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300
# 12        DS    Patel      F  300.0   NaN   88.0  100
# 13        XY    Patel      F  300.0   NaN   88.0  200
# 14        BC    Patel      F  300.0   NaN   88.0  300

# %%
df['DSBDA'].fillna(method = 'bfill', inplace = True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_31372\3131086941.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DSBDA'].fillna(method = 'bfill', inplace = True)
# C:\Users\sahil\AppData\Local\Temp\ipykernel_31372\3131086941.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['DSBDA'].fillna(method = 'bfill', inplace = True)

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    0.0    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    0.0    84   98.0   84
# 5         WS   Thakur      F   87.0    80   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0    87   93.0   96
# 10        MN    Desai      F  200.0    87   93.0  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300
# 12        DS    Patel      F  300.0   NaN   88.0  100
# 13        XY    Patel      F  300.0   NaN   88.0  200
# 14        BC    Patel      F  300.0   NaN   88.0  300

# %%
plt.boxplot(x = df['SPOS'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a2712f5f50>,
#   <matplotlib.lines.Line2D at 0x1a2712f5a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a2712c7f90>,
#   <matplotlib.lines.Line2D at 0x1a2712c5bd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a2712f6a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a2712c4910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a2712c4750>],
#  'means': []}

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    0.0    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    0.0    84   98.0   84
# 5         WS   Thakur      F   87.0    80   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0    87   93.0   96
# 10        MN    Desai      F  200.0    87   93.0  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300
# 12        DS    Patel      F  300.0   NaN   88.0  100
# 13        XY    Patel      F  300.0   NaN   88.0  200
# 14        BC    Patel      F  300.0   NaN   88.0  300

# %%
plt.figure(figsize=(6, 3))
sns.histplot(df['SPOS'], kde=True)
plt.title('Histogram before transformation')
plt.show()

# %%
print("Skewness before transformation:", df['SPOS'].skew())
# Out:
# Skewness before transformation: 0.6307296187611274

# %%
df['SPOS_log'] = np.log1p(df['SPOS'])

# %%
plt.figure(figsize=(6, 3))
sns.histplot(df['SPOS_log'], kde=True)
plt.title('Histogram after transformation')
plt.show()

# %%
print("Skewness after transformation:", df['SPOS_log'].skew())
# Out:
# Skewness after transformation: -1.1919552149929262

# %%
df.head()
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT  DA  SPOS_log
# 0        LA      Roy      M  85.0    88   90.0  92  4.454347
# 1        SA    Dixit      F  90.0    90   94.0  95  4.510860
# 2        AB   Danial      M   0.0    na  100.0  80  0.000000
# 3        DA   Kapoor      M  95.0    86  500.0  82  4.564348
# 4        SA      Jha      F   0.0    84   98.0  84  0.000000
