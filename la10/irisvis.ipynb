# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris.csv")
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print(np.unique(df["Species"]))
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2, 2, 1)
plt.hist(df["SepalLengthCm"], color='skyblue', edgecolor='black')
plt.title("Histogram of Sepal Length")
# Out:
# Text(0.5, 1.0, 'Histogram of Sepal Length')

# %%
plt.subplot(2, 2, 2)
plt.hist(df["SepalWidthCm"], color='lightgreen', edgecolor='black')
plt.title("Histogram of Sepal Width")
# Out:
# Text(0.5, 1.0, 'Histogram of Sepal Width')

# %%
plt.subplot(2, 2, 3)
plt.hist(df["PetalLengthCm"], color='salmon', edgecolor='black')
plt.title("Histogram of Petal Length")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Length')

# %%
plt.subplot(2, 2, 4)
plt.hist(df["PetalWidthCm"], color='plum', edgecolor='black')
plt.title("Histogram of Petal Width")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Width')

# %%
data_to_plot = [
    df["SepalLengthCm"],
    df["SepalWidthCm"],
    df["PetalLengthCm"],
    df["PetalWidthCm"]
]

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
ax.boxplot(data_to_plot, patch_artist=True, labels=["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"])
ax.set_title("Boxplot of Iris Dataset Features")
plt.ylabel("Centimeters")
plt.show()

# %%
fig = plt.figure(1, figsize=(12,8))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_to_plot)

# %%
print("\n--- Inference from Boxplots and Histograms ---")
print("1. SepalWidthCm shows a few outliers on the higher side.")
print("2. PetalLengthCm and PetalWidthCm are more concentrated and show clearer separation.")
print("3. Most features appear normally distributed, except SepalWidthCm which is slightly skewed.")
print("4. No major outliers in SepalLengthCm, PetalLengthCm, or PetalWidthCm.")
# Out:
# --- Inference from Boxplots and Histograms ---
# 1. SepalWidthCm shows a few outliers on the higher side.
# 2. PetalLengthCm and PetalWidthCm are more concentrated and show clearer separation.
# 3. Most features appear normally distributed, except SepalWidthCm which is slightly skewed.
# 4. No major outliers in SepalLengthCm, PetalLengthCm, or PetalWidthCm.
